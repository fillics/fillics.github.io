# %%
import pandas as pd

# %%
# https://en.wikipedia.org/wiki/List_of_municipalities_of_Sweden
# http://wikitable2csv.ggor.de/
muni = pd.read_csv(r'./living_cost_sweden/municipalities.csv')
muni.sample(10)
# Out:
#       Nr  Code             Municipality                  County  Population  \
# 81    82  1401     Härryda Municipality  Västra Götaland County       35636
# 277  278  2560     Älvsbyn Municipality       Norrbotten County        8182
# 40    41  1499   Falköping Municipality  Västra Götaland County       31923
# 253  254  2462  Vilhelmina Municipality     Västerbotten County        6924
# 216  217   181  Södertälje Municipality        Stockholm County       90677
# 56    57  2180       Gävle Municipality        Gävleborg County       96969
# 4      5  1984      Arboga Municipality      Västmanland County       13437
# 194  195  2422     Sorsele Municipality     Västerbotten County        2620
# 183  184  1291  Simrishamn Municipality            Skåne County       18900
# 242  243   760  Uppvidinge Municipality        Kronoberg County        9226
#
#      Total area (km²)  Land area (km²)  Inland water area (km²)  \
# 81             291.09           266.78                    24.31
# ...

# %%
# http://www.lonestatistik.se/loner.asp/yrke/Programmerare-1001
wages = pd.read_csv(r'./living_cost_sweden/it_wages.csv')
wages
# Out:
#                 Län   Medellön Medelålder Erfarenhet
# 0          Blekinge  29.140 kr      29 år       4 år
# 1           Dalarna  29.000 kr      33 år       8 år
# 2           Gotland  25.825 kr      32 år       8 år
# 3         Gävleborg  25.529 kr      30 år       4 år
# 4           Halland  27.418 kr      32 år       8 år
# 5          Jämtland  32.913 kr      36 år      12 år
# 6         Jönköping  32.982 kr      31 år       7 år
# 7            Kalmar  31.088 kr      33 år       8 år
# 8         Kronoberg  29.843 kr      30 år       6 år
# 9        Norrbotten  28.560 kr      33 år       5 år
# 10            Skåne  32.538 kr      33 år       7 år
# 11        Stockholm  35.194 kr      32 år       6 år
# 12     Södermanland  32.189 kr      31 år       7 år
# 13          Uppsala  30.704 kr      30 år       6 år
# 14         Värmland  32.902 kr      35 år       9 år
# 15     Västerbotten  27.211 kr      35 år       6 år
# 16   Västernorrland  30.412 kr      29 år       6 år
# ...

# %%
# http://www.statistikdatabasen.scb.se/pxweb/sv/ssd/START__HE__HE0202/HE0202T06/table/tableViewLayout1/
# ?rxid=ddccda22-c8fc-461a-9d50-c27bf861c804
consumption = pd.read_csv(r'./living_cost_sweden/consumption.csv')
consumption
# Out:
#   Konsumtionsutrymme, medianvärde, per hushåll, tkr efter region och år   2015
# 0                                           00 Riket                     249.4
# 1                                0010 Stor-Stockholm                     285.5
# 2                                 0020 Stor-Göteborg                     247.8
# 3  0042 Kommuner med > 75000 inv (exkl Stor-Stock...                     231.1
# 4  0043 Kommuner med < 75000 inv (exkl Stor-Stock...                     246.2

# %%
import plotly.plotly as py
import matplotlib.Basemap

# %%
# https://gadm.org/download_country.html
m = Basemap(projection='tmerc')
m.readshapefile("/path/to/your/shapefile", "mexican_states")

layout = dict(
        title = 'Sweden',
        geo = dict(
            scope='sweden',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict(data=wages, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# ---------------------------------------------------------------------------
# PlotlyDictValueError                      Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/plotly/tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#    1453         try:
# -> 1454             graph_objs.Figure(figure)
#    1455         except exceptions.PlotlyError as err:
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in __init__(self, *args, **kwargs)
#    1173     def __init__(self, *args, **kwargs):
# -> 1174         super(Figure, self).__init__(*args, **kwargs)
#    1175         if 'data' not in self:
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in __init__(self, *args, **kwargs)
#     376         for key, val in d.items():
# --> 377             self.__setitem__(key, val, _raise=_raise)
#     378
#
# ...

# %%
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-a62d01c1d62e> in <module>()
# ----> 1 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'
